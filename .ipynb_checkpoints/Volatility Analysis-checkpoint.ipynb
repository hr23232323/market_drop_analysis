# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 6]
import matplotlib.ticker as ticker
import seaborn as sns

# %%
# load data
df = pd.read_csv("./yahoo_change_data_3mon.csv")
df["Change%"] = df['Change%'].str.replace('%', '').astype('float')
display(df.head())
# Out:
#        Date         Open         High          Low        Close  Change%  \
# 0  1/2/2020  3244.669922  3258.139893  3235.530029  3257.850098     0.84
# 1  1/3/2020  3226.360107  3246.149902  3222.340088  3234.850098    -0.71
# 2  1/6/2020  3217.550049  3246.840088  3214.639893  3246.280029     0.35
# 3  1/7/2020  3241.860107  3244.909912  3232.429932  3237.179932    -0.28
# 4  1/8/2020  3238.590088  3267.070068  3236.669922  3253.050049     0.49
#
#          Volume
# 0  3.458250e+09
# 1  3.461290e+09
# 2  3.674070e+09
# 3  3.420380e+09
# 4  3.720890e+09

# %%
plt.style.use('seaborn-darkgrid')
fig, ax = plt.subplots()
ax.plot(df["Date"], df["Close"])
plt.xticks(rotation=30)
ax.set_xticks(ax.get_xticks()[::4])
plt.title("S&P 500 Change in Price over time", loc='left', fontsize=12, fontweight=0, color='black')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Value of S&P 500", fontsize=12)
plt.show()

# %%
plt.style.use('seaborn-darkgrid')

# Graph 1
fig, ax1 = plt.subplots(figsize=(14, 6))
ax1.plot(df["Date"], df["Close"])

# Graph 2

ax2 = ax1.twinx()
ax2.grid(False)
ax2.bar(df["Date"], df["Volume"], alpha=0.2)
ax2.get_xaxis().set_visible(False)

# Plot settings
plt.setp( ax1.xaxis.get_majorticklabels(), rotation=30 )
ax2.set_xticks(ax2.get_xticks()[::4])
plt.title("S&P 500 Change in Price over time", loc='left', fontsize=12, fontweight=0, color='black')
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Value of S&P 500", fontsize=12)
ax2.set_ylabel("Daily Volume", fontsize=12)
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: str(x)[:1] + " Billion"))

plt.show()

# %%
plt.style.use('seaborn-darkgrid')



df_t = df


df_t["scaled_change"] = df_t.apply(lambda row: abs((row["Change%"]-df_t["Change%"].mean())/(df_t["Change%"].std())), axis=1)
df_t["scaled_volume"] = df_t.apply(lambda row: abs((row["Volume"]-df_t["Volume"].mean())/(df_t["Volume"].std())), axis=1)

# Graph 1
fig, ax1 = plt.subplots(figsize=(16, 6))
w=0.4
ax1.bar(df_t.index, df_t["scaled_change"], width =w, alpha=0.4)
ax1.bar(df_t.index, df_t["scaled_volume"], width =w, alpha=0.4)


# Plot settings
plt.setp( ax1.xaxis.get_majorticklabels(), rotation=90 )
ax1.set_xticks(ax1.get_xticks()[::1])
plt.title("Change in ", loc='left', fontsize=12, fontweight=0, color='black')
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Sum of absolute Z-scores of volume and % Change", fontsize=12)
plt.show()

# %%
from statsmodels import robust

def mad(row, df_t, key):
    const = 0.6745
    data_point = row[key]
    median = df_t[key].median()
    med_abs_dev = robust.scale.mad(df_t[key])
    
    return (const * (data_point-median))/med_abs_dev

df_t["scaled_change"] = df_t.apply(lambda row: mad(row, df_t, "Change%"), axis=1)
df_t["scaled_volume"] = df_t.apply(lambda row: mad(row, df_t, "Volume"), axis=1)

df_t.tail(30).plot(x="Date", y=["scaled_change", "scaled_volume"], kind="bar", legend=True, title="Modified Z-Score over the last 30 days")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-b9b707a5ed55> in <module>
# ----> 1 from statsmodels import robust
#       2
#       3 def mad(row, df_t, key):
#       4     const = 0.6745
#       5     data_point = row[key]
#
# ModuleNotFoundError: No module named 'statsmodels'
